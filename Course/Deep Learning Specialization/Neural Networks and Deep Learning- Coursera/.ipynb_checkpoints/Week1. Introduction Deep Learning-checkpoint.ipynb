# %% [markdown]
# ## Week1: Introduction

# %% [markdown]
# ### Course summary

# %% [markdown]
# In this course, you will learn the foundations of deep learning. When you finish this class, you will:
# - Understand the major technology trends driving Deep Learning
# - Be able to build, train and apply fully connected deep neural networks
# - Know how to implement efficient(vectorized) neural networks
# - Understand the key parameters in a neural network's architecture

# %% [markdown]
# ### Course content
# 1. Neural Networks and Deep Learning(Ccat recognizer)
# 2. Improving Deep Neural Networks: Hyperparameter tuning, Regularization and Optimization
# 3. Structuring your Machine Learning project (end to end)
# 4. Convolutional Neural Networks
# 5. Natural Language Processing: Building sequence models (RNN, LSTM)

# %% [markdown]
# ### What is a (Neural Network) NN?
# - Single neuron == linear regression

# %% [markdown]
# ![Screen%20Shot%202019-01-13%20at%2016.11.52.png](attachment:Screen%20Shot%202019-01-13%20at%2016.11.52.png)

# %% [markdown]
# - Simple NN graph:input layer, hidden layer, output layer
# ![Screen%20Shot%202019-01-13%20at%2016.17.59.png](attachment:Screen%20Shot%202019-01-13%20at%2016.17.59.png)

# %% [markdown]
# [Q] every input layer feature is interconnected with every hidden layer feature.
# True

# %% [markdown]
# - Hidden layers predicts connection between inputs automatically, thats what deep learning is good at.
# - Supervised learning means we have the (X,Y) and we need to get the function that maps X to Y.
# - Deep NN consists of more hidden layers (Deeper layers)

# %% [markdown]
# ![Screen%20Shot%202019-01-13%20at%2016.23.50.png](attachment:Screen%20Shot%202019-01-13%20at%2016.23.50.png)

# %% [markdown]
# ### Supervised learning with neural networks
# ![Screen%20Shot%202019-01-13%20at%2016.40.34.png](attachment:Screen%20Shot%202019-01-13%20at%2016.40.34.png)

# %% [markdown]
# - Structured data is like the databases and tables.
# - Unstructured data is like images, video, audio, and text.
# - Structured data gives more money because companies relies on prediction on its big data.

# %% [markdown]
# Q? Would structured or unstructured data have features such as pixel values or individual words?
# Unstructured data

# %% [markdown]
# ### Why is Deep Learning taking off?
# Deep learning is taking off for 3 reasons:
# - i. Data:
#   - Using this image we can conclude:
#   ![Screen%20Shot%202019-01-13%20at%2017.10.42.png](attachment:Screen%20Shot%202019-01-13%20at%2017.10.42.png)
#   - For small data NN can perform as Linear regression or SVM (Support vector machine)
#   - For big data a small NN is better that SVM
#   - For big data a big NN is better that a medium NN is better that small NN.
#   - Hopefully we have a lot of data because the world is using the computer a little bit more：mobiles, IOT

# %% [markdown]
# - ii. Computation:
#   - GPUs.
#   - Powerful CPUs.
#   - Distributed computing
#   - ASICs

# %% [markdown]
# - iii. Algorithm:
#     - Creative algorithms has appeared that changed the way NN works.
#
# For example using RELU function is so much better than using SIGMOID function in training a NN because it helps with the vanishing gradient problem.

# %% [markdown]
# Q? What will the variable m denote in this course?
# Number of training examples
